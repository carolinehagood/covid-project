# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinehagood/covid-project/blob/main/DC-covid-deaths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('COVID-19_Death_Counts.csv')
df.head()
# Out:
#    Data as of  Start Date    End Date    Group       Year  Month  MMWR Week  \
# 0  10/03/2024  12/29/2019  01/04/2020  By Week  2019/2020    NaN        1.0
# 1  10/03/2024  01/05/2020  01/11/2020  By Week       2020    NaN        2.0
# 2  10/03/2024  01/12/2020  01/18/2020  By Week       2020    NaN        3.0
# 3  10/03/2024  01/19/2020  01/25/2020  By Week       2020    NaN        4.0
# 4  10/03/2024  01/26/2020  02/01/2020  By Week       2020    NaN        5.0
#
#   Week Ending Date          State  COVID-19 Deaths  Total Deaths  \
# 0       01/04/2020  United States              0.0       60170.0
# 1       01/11/2020  United States              1.0       60734.0
# 2       01/18/2020  United States              2.0       59362.0
# 3       01/25/2020  United States              3.0       59162.0
# 4       02/01/2020  United States              0.0       58834.0
#
#    Percent of Expected Deaths  Pneumonia Deaths  \
# 0                        98.0            4111.0
# 1                        97.0            4153.0
# 2                        98.0            4066.0
# 3                        99.0            3915.0
# 4                        99.0            3818.0
#
#    Pneumonia and COVID-19 Deaths  Influenza Deaths  \
# 0                            0.0             434.0
# 1                            1.0             475.0
# 2                            2.0             468.0
# 3                            0.0             500.0
# 4                            0.0             481.0
#
#    Pneumonia, Influenza, or COVID-19 Deaths Footnote
# 0                                    4545.0      NaN
# 1                                    4628.0      NaN
# 2                                    4534.0      NaN
# 3                                    4418.0      NaN
# 4                                    4299.0      NaN

# %%
#Data initialy had two rows that were messing with the rest of the data set.
#Resolved this manually in the terminal and editing the file, and then reuploading it
#This line of code confirms that the column names are now correct
column_names = df.columns
print(column_names)
# Out:
# Index(['Data as of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
#        'MMWR Week', 'Week Ending Date', 'State', 'COVID-19 Deaths',
#        'Total Deaths', 'Percent of Expected Deaths', 'Pneumonia Deaths',
#        'Pneumonia and COVID-19 Deaths', 'Influenza Deaths',
#        'Pneumonia, Influenza, or COVID-19 Deaths', 'Footnote'],
#       dtype='object')

# %%
#Delete all rows in which the state variable is not named "United States"
